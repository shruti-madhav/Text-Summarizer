# %%
print("hello world")
# Out:
# hello world

# %%
# %nvidia-smi
# Out:
# Sat Aug 31 20:44:49 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 457.34       Driver Version: 457.34       CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1650   WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P8     2W /  N/A |    213MiB /  4096MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1420    C+G   ...ser\Application\brave.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %%
# %pip install transformers[sentencepiece] datasets sacrebleu rouge_score py7zr -q
# Out:
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'C:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install --upgrade accelerate
# %pip uninstall -y transformers accelerate
# %pip install transformers accelerate

# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (2.4.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: filelock in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: jinja2 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip uninstall torch
# %pip install torch
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (2.4.0)
# Requirement already satisfied: jinja2 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: fsspec in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (1.13.2)
# Requirement already satisfied: filelock in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (3.15.4)
# Requirement already satisfied: networkx in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install pyarrow==14.0.1
# Out:
# Collecting pyarrow==14.0.1
#   Downloading pyarrow-14.0.1-cp310-cp310-win_amd64.whl (24.6 MB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\shrut\onedrive\desktop\text-summarizer\text\lib\site-packages (from pyarrow==14.0.1) (1.26.4)
# Installing collected packages: pyarrow
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\shrut\\OneDrive\\Desktop\\Text-Summarizer\\text\\Lib\\site-packages\\~yarrow\\arrow.dll'
# Check the permissions.
#
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install --force-reinstall cudf-cu12 ibis-framework
# Out:
# Collecting cudf-cu12
#   Downloading cudf_cu12-24.8.2.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#   Downloading cudf_cu12-24.8.1.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#   Downloading cudf_cu12-24.6.1.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#   Downloading cudf_cu12-24.6.0.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#   Downloading cudf_cu12-24.4.1.tar.gz (2.6 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#   Downloading cudf_cu12-24.4.0.tar.gz (2.7 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
#   Downloading cudf-cu12-24.2.2.tar.gz (6.9 kB)
#   Downloading cudf-cu12-24.2.1.tar.gz (6.9 kB)
#   Downloading cudf-cu12-24.2.0.tar.gz (6.9 kB)
#   Downloading cudf-cu12-23.12.1.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.12.0.post1.tar.gz (6.9 kB)
#   Downloading cudf-cu12-23.12.0.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.10.2.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.10.1.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.10.0.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.8.0.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.6.1.tar.gz (6.8 kB)
#   Downloading cudf-cu12-23.6.0.tar.gz (6.8 kB)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmp6r9bshp3'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_5947bc8a71f34d02b4eca084aa50331e
#     Complete output (64 lines):
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.2-cp310-cp310-manylinux_2_28_aarch64.whl against tag cp310-cp310-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.2-cp310-cp310-manylinux_2_28_x86_64.whl against tag cp310-cp310-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.2-cp311-cp311-manylinux_2_28_aarch64.whl against tag cp311-cp311-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.2-cp311-cp311-manylinux_2_28_x86_64.whl against tag cp311-cp311-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.2-cp39-cp39-manylinux_2_28_aarch64.whl against tag cp39-cp39-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.2-cp39-cp39-manylinux_2_28_x86_64.whl against tag cp39-cp39-manylinux_2_28_x86_64
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 143, in prepare_metadata_for_build_wheel
#         hook = backend.prepare_metadata_for_build_wheel
#     AttributeError: module 'nvidia_stub.buildapi' has no attribute 'prepare_metadata_for_build_wheel'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     RuntimeError: Didn't find wheel for cudf-cu12 24.8.2
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#         main()
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 147, in prepare_metadata_for_build_wheel
#         whl_basename = backend.build_wheel(metadata_directory, config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\buildapi.py", line 29, in build_wheel
#         return download_wheel(pathlib.Path(wheel_directory), config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 179, in download_wheel
#         report_install_failure(distribution, version, exception_context)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-p_a3aezv\overlay\Lib\site-packages\nvidia_stub\error.py", line 63, in report_install_failure
#         raise InstallFailedError(
#     nvidia_stub.error.InstallFailedError:
#     *******************************************************************************
#
#     The installation of cudf-cu12 for version 24.8.2 failed.
#
#     This is a special placeholder package which downloads a real wheel package
#     from https://pypi.nvidia.com. If https://pypi.nvidia.com is not reachable, we
#     cannot download the real wheel file to install.
#
#     You might try installing this package via
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#
#     Here is some debug information about your platform to include in any bug
#     report:
#
#     Python Version: CPython 3.10.0
#     Operating System: Windows 10
#     CPU Architecture: AMD64
#     Driver Version: 457.34
#     CUDA Version: 11.1
#
#     *******************************************************************************
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0a/31/addddbd669f8f7649106842eee155bde36096be7b54fd1abb6a581dddfdf/cudf_cu12-24.8.2.tar.gz#sha256=0e46db69b59631c4cc869314faa7ef8fad9bb46d26f517f479a292948c1c6949 (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmp6r9bshp3' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpk_q0y_9b'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_63f4d0c1397c4cbe84965f0a102a7824
#     Complete output (64 lines):
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.1-cp310-cp310-manylinux_2_28_aarch64.whl against tag cp310-cp310-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.1-cp310-cp310-manylinux_2_28_x86_64.whl against tag cp310-cp310-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.1-cp311-cp311-manylinux_2_28_aarch64.whl against tag cp311-cp311-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.1-cp311-cp311-manylinux_2_28_x86_64.whl against tag cp311-cp311-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.1-cp39-cp39-manylinux_2_28_aarch64.whl against tag cp39-cp39-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.8.1-cp39-cp39-manylinux_2_28_x86_64.whl against tag cp39-cp39-manylinux_2_28_x86_64
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 143, in prepare_metadata_for_build_wheel
#         hook = backend.prepare_metadata_for_build_wheel
#     AttributeError: module 'nvidia_stub.buildapi' has no attribute 'prepare_metadata_for_build_wheel'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     RuntimeError: Didn't find wheel for cudf-cu12 24.8.1
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#         main()
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 147, in prepare_metadata_for_build_wheel
#         whl_basename = backend.build_wheel(metadata_directory, config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\buildapi.py", line 29, in build_wheel
#         return download_wheel(pathlib.Path(wheel_directory), config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 179, in download_wheel
#         report_install_failure(distribution, version, exception_context)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-292fyo5w\overlay\Lib\site-packages\nvidia_stub\error.py", line 63, in report_install_failure
#         raise InstallFailedError(
#     nvidia_stub.error.InstallFailedError:
#     *******************************************************************************
#
#     The installation of cudf-cu12 for version 24.8.1 failed.
#
#     This is a special placeholder package which downloads a real wheel package
#     from https://pypi.nvidia.com. If https://pypi.nvidia.com is not reachable, we
#     cannot download the real wheel file to install.
#
#     You might try installing this package via
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#
#     Here is some debug information about your platform to include in any bug
#     report:
#
#     Python Version: CPython 3.10.0
#     Operating System: Windows 10
#     CPU Architecture: AMD64
#     Driver Version: 457.34
#     CUDA Version: 11.1
#
#     *******************************************************************************
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/65/7e/e8e9952bc99c3cd1d241476effd83f32c7abd56af16af598445c10a61bf8/cudf_cu12-24.8.1.tar.gz#sha256=5fdc9d2cc5bb173fc5e5dcfde81b15140f82ef3a00d210b449c2723b4a8560bc (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpk_q0y_9b' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpkl86877j'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_9a2563dbba24440e995890b35fef8f63
#     Complete output (64 lines):
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.1-cp310-cp310-manylinux_2_28_aarch64.whl against tag cp310-cp310-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.1-cp310-cp310-manylinux_2_28_x86_64.whl against tag cp310-cp310-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.1-cp311-cp311-manylinux_2_28_aarch64.whl against tag cp311-cp311-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.1-cp311-cp311-manylinux_2_28_x86_64.whl against tag cp311-cp311-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.1-cp39-cp39-manylinux_2_28_aarch64.whl against tag cp39-cp39-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.1-cp39-cp39-manylinux_2_28_x86_64.whl against tag cp39-cp39-manylinux_2_28_x86_64
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 143, in prepare_metadata_for_build_wheel
#         hook = backend.prepare_metadata_for_build_wheel
#     AttributeError: module 'nvidia_stub.buildapi' has no attribute 'prepare_metadata_for_build_wheel'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     RuntimeError: Didn't find wheel for cudf-cu12 24.6.1
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#         main()
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 147, in prepare_metadata_for_build_wheel
#         whl_basename = backend.build_wheel(metadata_directory, config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\buildapi.py", line 29, in build_wheel
#         return download_wheel(pathlib.Path(wheel_directory), config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 179, in download_wheel
#         report_install_failure(distribution, version, exception_context)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-3p5bxude\overlay\Lib\site-packages\nvidia_stub\error.py", line 63, in report_install_failure
#         raise InstallFailedError(
#     nvidia_stub.error.InstallFailedError:
#     *******************************************************************************
#
#     The installation of cudf-cu12 for version 24.6.1 failed.
#
#     This is a special placeholder package which downloads a real wheel package
#     from https://pypi.nvidia.com. If https://pypi.nvidia.com is not reachable, we
#     cannot download the real wheel file to install.
#
#     You might try installing this package via
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#
#     Here is some debug information about your platform to include in any bug
#     report:
#
#     Python Version: CPython 3.10.0
#     Operating System: Windows 10
#     CPU Architecture: AMD64
#     Driver Version: 457.34
#     CUDA Version: 11.1
#
#     *******************************************************************************
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e1/88/91fb044f89c395f88154a331d995a4ab800ef8f81309bdfd29344a13f264/cudf_cu12-24.6.1.tar.gz#sha256=8f98a0d469d2596f06702c3a730fc2dc5f49526693e65bdedbd65c9036037fe7 (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpkl86877j' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpv0rtosil'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_dbf0518bbfc54ad591db52e87458a7cc
#     Complete output (64 lines):
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.0-cp310-cp310-manylinux_2_28_aarch64.whl against tag cp310-cp310-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.0-cp310-cp310-manylinux_2_28_x86_64.whl against tag cp310-cp310-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.0-cp311-cp311-manylinux_2_28_aarch64.whl against tag cp311-cp311-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.0-cp311-cp311-manylinux_2_28_x86_64.whl against tag cp311-cp311-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.0-cp39-cp39-manylinux_2_28_aarch64.whl against tag cp39-cp39-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.6.0-cp39-cp39-manylinux_2_28_x86_64.whl against tag cp39-cp39-manylinux_2_28_x86_64
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 143, in prepare_metadata_for_build_wheel
#         hook = backend.prepare_metadata_for_build_wheel
#     AttributeError: module 'nvidia_stub.buildapi' has no attribute 'prepare_metadata_for_build_wheel'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     RuntimeError: Didn't find wheel for cudf-cu12 24.6.0
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#         main()
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 147, in prepare_metadata_for_build_wheel
#         whl_basename = backend.build_wheel(metadata_directory, config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\buildapi.py", line 29, in build_wheel
#         return download_wheel(pathlib.Path(wheel_directory), config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 179, in download_wheel
#         report_install_failure(distribution, version, exception_context)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-_5h_qdfk\overlay\Lib\site-packages\nvidia_stub\error.py", line 63, in report_install_failure
#         raise InstallFailedError(
#     nvidia_stub.error.InstallFailedError:
#     *******************************************************************************
#
#     The installation of cudf-cu12 for version 24.6.0 failed.
#
#     This is a special placeholder package which downloads a real wheel package
#     from https://pypi.nvidia.com. If https://pypi.nvidia.com is not reachable, we
#     cannot download the real wheel file to install.
#
#     You might try installing this package via
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#
#     Here is some debug information about your platform to include in any bug
#     report:
#
#     Python Version: CPython 3.10.0
#     Operating System: Windows 10
#     CPU Architecture: AMD64
#     Driver Version: 457.34
#     CUDA Version: 11.1
#
#     *******************************************************************************
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/d1/98/0e55a49dff0d054fb60cba02b37a44539fe68b8a352d0fe6df9591f08c6e/cudf_cu12-24.6.0.tar.gz#sha256=72012b3f05bab2cf3eccfbf71ce80cd10c01adeae0dbeb96589989c12d7c9aa6 (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpv0rtosil' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmp5daeqw36'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_1baaae0f033c4b08a59ab5df904989cc
#     Complete output (70 lines):
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp310-cp310-manylinux2014_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp310-cp310-manylinux_2_17_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp310-cp310-manylinux_2_28_aarch64.whl against tag cp310-cp310-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp310-cp310-manylinux_2_28_x86_64.whl against tag cp310-cp310-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp311-cp311-manylinux2014_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp311-cp311-manylinux_2_17_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp311-cp311-manylinux_2_28_aarch64.whl against tag cp311-cp311-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp311-cp311-manylinux_2_28_x86_64.whl against tag cp311-cp311-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp39-cp39-manylinux_2_17_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp39-cp39-manylinux2014_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp39-cp39-manylinux_2_28_aarch64.whl against tag cp39-cp39-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.1-cp39-cp39-manylinux_2_28_x86_64.whl against tag cp39-cp39-manylinux_2_28_x86_64
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 143, in prepare_metadata_for_build_wheel
#         hook = backend.prepare_metadata_for_build_wheel
#     AttributeError: module 'nvidia_stub.buildapi' has no attribute 'prepare_metadata_for_build_wheel'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     RuntimeError: Didn't find wheel for cudf-cu12 24.4.1
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#         main()
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 147, in prepare_metadata_for_build_wheel
#         whl_basename = backend.build_wheel(metadata_directory, config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\buildapi.py", line 29, in build_wheel
#         return download_wheel(pathlib.Path(wheel_directory), config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 179, in download_wheel
#         report_install_failure(distribution, version, exception_context)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-6t6bp7cv\overlay\Lib\site-packages\nvidia_stub\error.py", line 63, in report_install_failure
#         raise InstallFailedError(
#     nvidia_stub.error.InstallFailedError:
#     *******************************************************************************
#
#     The installation of cudf-cu12 for version 24.4.1 failed.
#
#     This is a special placeholder package which downloads a real wheel package
#     from https://pypi.nvidia.com. If https://pypi.nvidia.com is not reachable, we
#     cannot download the real wheel file to install.
#
#     You might try installing this package via
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#
#     Here is some debug information about your platform to include in any bug
#     report:
#
#     Python Version: CPython 3.10.0
#     Operating System: Windows 10
#     CPU Architecture: AMD64
#     Driver Version: 457.34
#     CUDA Version: 11.1
#
#     *******************************************************************************
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/98/9d/17c6c36eef1f148d10588fed321dc44f17c3464784b887381a3bb363f637/cudf_cu12-24.4.1.tar.gz#sha256=9d3f8d0bd44cbfeb19176b6ef3c7193b5608863e5b1f64a7e58aac732b0118cb (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmp5daeqw36' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpjbs4px4x'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_2b4670c5bc664380b7e10b12e6433607
#     Complete output (70 lines):
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp310-cp310-manylinux_2_17_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp310-cp310-manylinux2014_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp310-cp310-manylinux_2_28_aarch64.whl against tag cp310-cp310-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp310-cp310-manylinux_2_28_x86_64.whl against tag cp310-cp310-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp311-cp311-manylinux2014_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp311-cp311-manylinux_2_17_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp311-cp311-manylinux_2_28_aarch64.whl against tag cp311-cp311-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp311-cp311-manylinux_2_28_x86_64.whl against tag cp311-cp311-manylinux_2_28_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp39-cp39-manylinux2014_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl against tag cp39-cp39-manylinux_2_17_x86_64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp39-cp39-manylinux_2_28_aarch64.whl against tag cp39-cp39-manylinux_2_28_aarch64
#     INFO:nvidia-stub:Testing wheel cudf_cu12-24.4.0-cp39-cp39-manylinux_2_28_x86_64.whl against tag cp39-cp39-manylinux_2_28_x86_64
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 143, in prepare_metadata_for_build_wheel
#         hook = backend.prepare_metadata_for_build_wheel
#     AttributeError: module 'nvidia_stub.buildapi' has no attribute 'prepare_metadata_for_build_wheel'
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 177, in download_wheel
#         return download_manual(wheel_directory, distribution, version)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 144, in download_manual
#         raise RuntimeError(f"Didn't find wheel for {distribution} {version}")
#     RuntimeError: Didn't find wheel for cudf-cu12 24.4.0
#
#     During handling of the above exception, another exception occurred:
#
#     Traceback (most recent call last):
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 349, in <module>
#         main()
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 331, in main
#         json_out['return_val'] = hook(**hook_input['kwargs'])
#       File "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py", line 147, in prepare_metadata_for_build_wheel
#         whl_basename = backend.build_wheel(metadata_directory, config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\buildapi.py", line 29, in build_wheel
#         return download_wheel(pathlib.Path(wheel_directory), config_settings)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\wheel.py", line 179, in download_wheel
#         report_install_failure(distribution, version, exception_context)
#       File "C:\Users\shrut\AppData\Local\Temp\pip-build-env-41t1p96v\overlay\Lib\site-packages\nvidia_stub\error.py", line 63, in report_install_failure
#         raise InstallFailedError(
#     nvidia_stub.error.InstallFailedError:
#     *******************************************************************************
#
#     The installation of cudf-cu12 for version 24.4.0 failed.
#
#     This is a special placeholder package which downloads a real wheel package
#     from https://pypi.nvidia.com. If https://pypi.nvidia.com is not reachable, we
#     cannot download the real wheel file to install.
#
#     You might try installing this package via
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#
#     Here is some debug information about your platform to include in any bug
#     report:
#
#     Python Version: CPython 3.10.0
#     Operating System: Windows 10
#     CPU Architecture: AMD64
#     Driver Version: 457.34
#     CUDA Version: 11.1
#
#     *******************************************************************************
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/8c/52/c186b184d9a7cba9f867256b9830c36a4ba1fdbd782d8f763a220d78356d/cudf_cu12-24.4.0.tar.gz#sha256=25ae1b0253a09f43df8427feb1f9aadfbd5ff7aba6736dae6bf65b359445dd9b (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' prepare_metadata_for_build_wheel 'C:\Users\shrut\AppData\Local\Temp\tmpjbs4px4x' Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_9a0bbece161a41a7aa93a29a7ea73d07\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_9a0bbece161a41a7aa93a29a7ea73d07\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-iyf8c4a3'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_9a0bbece161a41a7aa93a29a7ea73d07\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_9a0bbece161a41a7aa93a29a7ea73d07\setup.py", line 90, in <module>
#         raise RuntimeError("Bad params")
#     RuntimeError: Bad params
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/93/c7/02f60c4b84d877ef740c66e5701d055f6324da99c948e536591897340ad8/cudf-cu12-24.2.2.tar.gz#sha256=64b4826372b592723842157a700bdc7a14fc46b891c75b7860834bf38562bf78 (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_129749874d734c8d86ca715ab1b740d9\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_129749874d734c8d86ca715ab1b740d9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-_6ujs6gv'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_129749874d734c8d86ca715ab1b740d9\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_129749874d734c8d86ca715ab1b740d9\setup.py", line 90, in <module>
#         raise RuntimeError("Bad params")
#     RuntimeError: Bad params
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/36/fd/bc2b905e07d0a0481377c7cb3fbb8e4c34fde1a5e14510f372752ef7679c/cudf-cu12-24.2.1.tar.gz#sha256=5b1d88af008b5b16a53c911fe764c7475baace87602750dba29b1eddc447b1f9 (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_83fa7e6fc6f34b29a6e0514b72e98571\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_83fa7e6fc6f34b29a6e0514b72e98571\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-md3iqeb1'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_83fa7e6fc6f34b29a6e0514b72e98571\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_83fa7e6fc6f34b29a6e0514b72e98571\setup.py", line 90, in <module>
#         raise RuntimeError("Bad params")
#     RuntimeError: Bad params
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/98/89/3c1b710c12b4e7225782c82de29e8b723f15edc26a77d0b8f7ba8c6bc87c/cudf-cu12-24.2.0.tar.gz#sha256=1bc4e1e6730f0dff2a6cb6fe86348be4ee6d0ff889e64e1c4a7f8422d8eac8ea (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_da2e5dc7656443cdb5b39b7914c6aba8\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_da2e5dc7656443cdb5b39b7914c6aba8\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-4noejd7q'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_da2e5dc7656443cdb5b39b7914c6aba8\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_da2e5dc7656443cdb5b39b7914c6aba8\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --no-cache-dir --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/cb/7e/41f34e885b7b09f9989f8ca3397d061c86fad0d1399113222573e003f089/cudf-cu12-23.12.1.tar.gz#sha256=6308890b8eb9269fe81cfcd01f1846f2bac1adcbc8787caebd238a955f8eccbe (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_62c0a75e8a3a421382049492501374ff\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_62c0a75e8a3a421382049492501374ff\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-eac_s4o0'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_62c0a75e8a3a421382049492501374ff\
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_62c0a75e8a3a421382049492501374ff\setup.py", line 90, in <module>
#         raise RuntimeError("Bad params")
#     RuntimeError: Bad params
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b5/e6/cd5f73f16d3296e67e68e0c4b9394c6d7436a3fb8ceae8b653763cc6eba2/cudf-cu12-23.12.0.post1.tar.gz#sha256=d493f40337859968c3b074de0b617396f61a591e9f71911eded0e28b77a75aec (from https://pypi.org/simple/cudf-cu12/) (requires-python:>=3.9). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_a02c9186e0a5422a8f941fe561792a29\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_a02c9186e0a5422a8f941fe561792a29\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-92_2otk4'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_a02c9186e0a5422a8f941fe561792a29\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_a02c9186e0a5422a8f941fe561792a29\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --no-cache-dir --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/de/df/acb68ab1fbeac25d405259946782162c2822f642fe79a2d46329b33951c5/cudf-cu12-23.12.0.tar.gz#sha256=2e7256261b726b64863e63018af78b894e637e3f811ec116339a241632097420 (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_e4c9e1c1bb8649429872ea9ae6c92b0e\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_e4c9e1c1bb8649429872ea9ae6c92b0e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-odufr9_x'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_e4c9e1c1bb8649429872ea9ae6c92b0e\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_e4c9e1c1bb8649429872ea9ae6c92b0e\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --no-cache-dir --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/42/2b/5c6cede0734ff469a0393b7cd716caf875f1d0359fd1ca75d421fa664555/cudf-cu12-23.10.2.tar.gz#sha256=cfd5b4954b34d5cf4549e2136e1f161598914799313773e11d71e8e61ce4f7f0 (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_2b78416b6084472ab7a9cac5bff4a7be\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_2b78416b6084472ab7a9cac5bff4a7be\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-m0_uuwmq'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_2b78416b6084472ab7a9cac5bff4a7be\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_2b78416b6084472ab7a9cac5bff4a7be\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --no-cache-dir --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/19/14/cb7fbf0a9f47ebe39b9b85d408243498272af0ffadc399ca96ad44d3729a/cudf-cu12-23.10.1.tar.gz#sha256=40ffdc348a04ec88fa98072dd909dc72ee79ad281464374fa7a4532f83f7407a (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_e714dc7a38ee45c2bf1e03a2a7afc765\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_e714dc7a38ee45c2bf1e03a2a7afc765\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-47dto2xz'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_e714dc7a38ee45c2bf1e03a2a7afc765\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_e714dc7a38ee45c2bf1e03a2a7afc765\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --no-cache-dir --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/e1/41/05ed76f9ff403eb0e8c9bc9ff2c44cfddc7fcbca029a15d27a459ef752e1/cudf-cu12-23.10.0.tar.gz#sha256=2ebcec1d804554a0f70f81a814713974b2eb31d55ac39b4ebdbd3962be93f05c (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_9a1effbc67514a17aa1ad282c82e40dd\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_9a1effbc67514a17aa1ad282c82e40dd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-fujh49zx'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_9a1effbc67514a17aa1ad282c82e40dd\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_9a1effbc67514a17aa1ad282c82e40dd\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/61/15/b378ff110c11fe938a0d3ffb945acc105370499872358cab5c9fb0affce1/cudf-cu12-23.8.0.tar.gz#sha256=8dfa38c75d0643bcd0116990e3fc9527b4a2d2446bdf975fb7183b9ad408bf99 (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_1bf8e9c33b4d43739c9b8fa2d5002dff\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_1bf8e9c33b4d43739c9b8fa2d5002dff\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-ws144z9p'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_1bf8e9c33b4d43739c9b8fa2d5002dff\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_1bf8e9c33b4d43739c9b8fa2d5002dff\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/27/6ff33ebba03239855e750a9f0203451531ebda83630dbc769da6daa65850/cudf-cu12-23.6.1.tar.gz#sha256=96b44b5aaf84a6ce0f3879ff661f28011a3881c003a3c556fc930a5953e3c942 (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_27fcbfc133ec4b0e9faa3db9a8dcfdd5\\setup.py'"'"'; __file__='"'"'C:\\Users\\shrut\\AppData\\Local\\Temp\\pip-install-tbdjib3g\\cudf-cu12_27fcbfc133ec4b0e9faa3db9a8dcfdd5\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\shrut\AppData\Local\Temp\pip-pip-egg-info-s3geu704'
#          cwd: C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_27fcbfc133ec4b0e9faa3db9a8dcfdd5\
#     Complete output (15 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\shrut\AppData\Local\Temp\pip-install-tbdjib3g\cudf-cu12_27fcbfc133ec4b0e9faa3db9a8dcfdd5\setup.py", line 137, in <module>
#         raise RuntimeError(open("ERROR.txt", "r").read())
#     RuntimeError:
#     ###########################################################################################
#     The package you are trying to install is only a placeholder project on PyPI.org repository.
#     This package is hosted on NVIDIA Python Package Index.
#
#     This package can be installed as:
#     ```
#     $ pip install --extra-index-url https://pypi.nvidia.com cudf-cu12
#     ```
#     ###########################################################################################
#
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0a/55/278481a711c5bec96f8f89dae06fb9e4d9c61c0faeea622cc3246c912145/cudf-cu12-23.6.0.tar.gz#sha256=1d420712722cf0d1fabbb0923a9af10d4fd9eb9450f61bfd558c2f9210c11922 (from https://pypi.org/simple/cudf-cu12/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement cudf-cu12 (from versions: 23.6.0, 23.6.1, 23.8.0, 23.10.0, 23.10.1, 23.10.2, 23.12.0, 23.12.0.post1, 23.12.1, 24.2.0, 24.2.1, 24.2.2, 24.4.0, 24.4.1, 24.6.0, 24.6.1, 24.8.1, 24.8.2)
# ERROR: No matching distribution found for cudf-cu12
# WARNING: You are using pip version 21.2.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import nltk
import pandas as pd
import matplotlib.pyplot as plt
from transformers import pipeline, set_seed
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datasets import load_datasets, load_from_disk, load_metric
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 from transformers import pipeline, set_seed
#       5 from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
#       6 from datasets import load_datasets, load_from_disk, load_metric
#
# File c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\transformers\__init__.py:26
#      23 from typing import TYPE_CHECKING
#      25 # Check the dependencies satisfy the minimal versions required.
# ---> 26 from . import dependency_versions_check
#      27 from .utils import (
#      28     OptionalDependencyNotAvailable,
#      29     _LazyModule,
#    (...)
#      48     logging,
#      49 )
#      52 logger = logging.get_logger(__name__)  # pylint: disable=invalid-name
#
# File c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\transformers\dependency_versions_check.py:16
#       1 # Copyright 2020 The HuggingFace Team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      19 # define which module versions we always want to check at run time
#      20 # (usually the ones defined in `install_requires` in setup.py)
#      21 #
#      22 # order specific notes:
#      23 # - tqdm must be checked before tokenizers
#      25 pkgs_to_check_at_runtime = [
#      26     "python",
#      27     "tqdm",
#    (...)
#      37     "pyyaml",
#      38 ]
#
# File c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\transformers\utils\__init__.py:34
#      25 from .constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_STANDARD_MEAN, IMAGENET_STANDARD_STD
#      26 from .doc import (
#      27     add_code_sample_docstrings,
#      28     add_end_docstrings,
#    (...)
#      32     replace_return_docstrings,
#      33 )
# ---> 34 from .generic import (
#      35     ContextManagers,
#      36     ExplicitEnum,
#      37     ModelOutput,
#      38     PaddingStrategy,
#      39     TensorType,
#      40     add_model_info_to_auto_map,
#      41     add_model_info_to_custom_pipelines,
#      42     cached_property,
#      43     can_return_loss,
#      44     expand_dims,
#      45     filter_out_non_signature_kwargs,
#      46     find_labels,
#      47     flatten_dict,
#      48     infer_framework,
#      49     is_jax_tensor,
#      50     is_numpy_array,
#      51     is_tensor,
#      52     is_tf_symbolic_tensor,
#      53     is_tf_tensor,
#      54     is_torch_device,
#      55     is_torch_dtype,
#      56     is_torch_tensor,
#      57     reshape,
#      58     squeeze,
#      59     strtobool,
#      60     tensor_size,
#      61     to_numpy,
#      62     to_py_obj,
#      63     torch_float,
#      64     torch_int,
#      65     transpose,
#      66     working_or_temp_dir,
#      67 )
#      68 from .hub import (
#      69     CLOUDFRONT_DISTRIB_PREFIX,
#      70     HF_MODULES_CACHE,
#    (...)
#      96     try_to_load_from_cache,
#      97 )
#      98 from .import_utils import (
#      99     ACCELERATE_MIN_VERSION,
#     100     ENV_VARS_TRUE_AND_AUTO_VALUES,
#    (...)
#     219     torch_only_method,
#     220 )
#
# File c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\transformers\utils\generic.py:462
#     458         return tuple(self[k] for k in self.keys())
#     461 if is_torch_available():
# --> 462     import torch.utils._pytree as _torch_pytree
#     464     def _model_output_flatten(output: ModelOutput) -> Tuple[List[Any], "_torch_pytree.Context"]:
#     465         return list(output.values()), list(output.keys())
#
# File c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "c:\Users\shrut\OneDrive\Desktop\Text-Summarizer\text\lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.
